# %%
# Shi-Tomasi Corner Detection
# Para identificação de bordas na imagem
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# leitura da imagem
xadrez = cv2.imread('../../assets/xadrez.jpeg')
xadrez = cv2.cvtColor(xadrez, cv2.COLOR_BGR2RGB)
plt.imshow(xadrez)

# %%
# imagem cinza
grayXadrez = cv2.cvtColor(xadrez, cv2.COLOR_BGR2GRAY)
plt.imshow(grayXadrez, cmap='gray')

# %%
# aplicando o algoritmo
edges = cv2.goodFeaturesToTrack(grayXadrez, 100, 0.01, 10)
edges
# Out:
# array([[[1180., 1180.]],
#
#        [[   3., 1180.]],
#
#        [[1180.,    3.]],
#
#        [[   3.,    3.]],
#
#        [[ 137., 1040.]],
#
#        [[ 595.,  377.]],
#
#        [[1120., 1114.]],
#
#        [[  58., 1114.]],
#
#        [[ 822.,  486.]],
#
#        [[ 595.,  486.]],
#
#        [[ 817.,  269.]],
#
#        [[ 595.,  705.]],
#
#        [[ 592.,  268.]],
#
#        [[ 706.,  707.]],
#
#        [[ 366.,  706.]],
#
#        [[ 707.,  815.]],
#
#        [[ 821.,  597.]],
#
#        [[ 369.,  378.]],
#
#        [[ 706.,  379.]],
#
#        [[ 707.,  488.]],
#
#        [[ 933.,  488.]],
#
#        [[ 482.,  813.]],
#
#        [[ 818.,  813.]],
#
#        [[ 593.,  597.]],
#
#        [[ 480.,  706.]],
#
#        [[ 708.,  597.]],
#
#        [[ 254.,  814.]],
#
#        [[ 932.,  705.]],
#
#        [[1045.,  272.]],
#
#        [[1123.,   79.]],
#
#        [[ 480.,  485.]],
#
#        [[ 933.,  378.]],
#
#        [[ 254.,  486.]],
#
#        [[ 480.,  376.]],
#
#        [[ 366.,  923.]],
#
#        [[ 366.,  597.]],
#
#        [[ 933.,  598.]],
#
#        [[ 819.,  380.]],
#
#        [[ 816.,  921.]],
#
#        [[ 370.,  485.]],
#
#        [[ 705.,  268.]],
#
#        [[ 704.,  921.]],
#
#        [[ 480.,  595.]],
#
#        [[ 931.,  813.]],
#
#        [[ 592.,  815.]],
#
#        [[ 366.,  813.]],
#
#        [[ 819.,  707.]],
#
#        [[ 932.,  272.]],
#
#        [[ 253.,  704.]],
#
#        [[ 930.,  923.]],
#
#        [[ 481.,  923.]],
#
#        [[1044., 1059.]],
#
#        [[ 253.,  598.]],
#
#        [[ 478.,  267.]],
#
#        [[ 592.,  921.]],
#
#        [[ 257.,  377.]],
#
#        [[ 945., 1062.]],
#
#        [[ 254.,  920.]],
#
#        [[ 594.,  156.]],
#
#        [[ 139.,  486.]],
#
#        [[ 138.,  598.]],
#
#        [[ 138.,  704.]],
#
#        [[ 254.,  158.]],
#
#        [[ 369.,  270.]],
#
#        [[ 818.,  158.]],
#
#        [[ 253.,  268.]],
#
#        [[1045.,  380.]],
#
#        [[ 703.,  157.]],
#
#        [[ 925., 1033.]],
#
#        [[ 140.,  269.]],
#
#        [[ 139.,  380.]],
#
#        [[1047.,  158.]],
#
#        [[ 141.,  919.]],
#
#        [[ 479.,  156.]],
#
#        [[ 368., 1035.]],
#
#        [[ 254., 1032.]],
#
#        [[ 817., 1034.]],
#
#        [[ 478., 1035.]],
#
#        [[1045.,  595.]],
#
#        [[1046.,  490.]],
#
#        [[1044.,  707.]],
#
#        [[ 593., 1037.]],
#
#        [[ 927.,  159.]],
#
#        [[1043.,  812.]],
#
#        [[ 702., 1036.]],
#
#        [[  58.,   81.]],
#
#        [[  58.,  165.]],
#
#        [[ 138.,  815.]],
#
#        [[ 873.,   79.]],
#
#        [[ 941., 1051.]],
#
#        [[1040.,  922.]],
#
#        [[ 142.,  161.]],
#
#        [[  58.,  220.]],
#
#        [[  59.,  141.]],
#
#        [[ 813.,   78.]],
#
#        [[ 973., 1068.]],
#
#        [[1051., 1068.]],
#
#        [[ 548.,   79.]],
#
#        [[ 951.,   79.]],
#
#        [[ 131.,  298.]]], dtype=float32)

# %%
# converter para inteiro
edges = np.int0(edges)
edges
# Out:
# /var/folders/xb/9xj62y794n3_9q3z4tbt47yc0000gn/T/ipykernel_84945/3187730124.py:2: DeprecationWarning: `np.int0` is a deprecated alias for `np.intp`.  (Deprecated NumPy 1.24)
#   edges = np.int0(edges)
# array([[[1180, 1180]],
#
#        [[   3, 1180]],
#
#        [[1180,    3]],
#
#        [[   3,    3]],
#
#        [[ 137, 1040]],
#
#        [[ 595,  377]],
#
#        [[1120, 1114]],
#
#        [[  58, 1114]],
#
#        [[ 822,  486]],
#
#        [[ 595,  486]],
#
#        [[ 817,  269]],
#
#        [[ 595,  705]],
#
#        [[ 592,  268]],
#
#        [[ 706,  707]],
#
#        [[ 366,  706]],
#
#        [[ 707,  815]],
#
#        [[ 821,  597]],
#
#        [[ 369,  378]],
#
#        [[ 706,  379]],
#
#        [[ 707,  488]],
#
#        [[ 933,  488]],
#
#        [[ 482,  813]],
#
#        [[ 818,  813]],
#
#        [[ 593,  597]],
#
#        [[ 480,  706]],
#
#        [[ 708,  597]],
#
#        [[ 254,  814]],
#
#        [[ 932,  705]],
#
#        [[1045,  272]],
#
#        [[1123,   79]],
#
#        [[ 480,  485]],
#
#        [[ 933,  378]],
#
#        [[ 254,  486]],
#
#        [[ 480,  376]],
#
#        [[ 366,  923]],
#
#        [[ 366,  597]],
#
#        [[ 933,  598]],
#
#        [[ 819,  380]],
#
#        [[ 816,  921]],
#
#        [[ 370,  485]],
#
#        [[ 705,  268]],
#
#        [[ 704,  921]],
#
#        [[ 480,  595]],
#
#        [[ 931,  813]],
#
#        [[ 592,  815]],
#
#        [[ 366,  813]],
#
#        [[ 819,  707]],
#
#        [[ 932,  272]],
#
#        [[ 253,  704]],
#
#        [[ 930,  923]],
#
#        [[ 481,  923]],
#
#        [[1044, 1059]],
#
#        [[ 253,  598]],
#
#        [[ 478,  267]],
#
#        [[ 592,  921]],
#
#        [[ 257,  377]],
#
#        [[ 945, 1062]],
#
#        [[ 254,  920]],
#
#        [[ 594,  156]],
#
#        [[ 139,  486]],
#
#        [[ 138,  598]],
#
#        [[ 138,  704]],
#
#        [[ 254,  158]],
#
#        [[ 369,  270]],
#
#        [[ 818,  158]],
#
#        [[ 253,  268]],
#
#        [[1045,  380]],
#
#        [[ 703,  157]],
#
#        [[ 925, 1033]],
#
#        [[ 140,  269]],
#
#        [[ 139,  380]],
#
#        [[1047,  158]],
#
#        [[ 141,  919]],
#
#        [[ 479,  156]],
#
#        [[ 368, 1035]],
#
#        [[ 254, 1032]],
#
#        [[ 817, 1034]],
#
#        [[ 478, 1035]],
#
#        [[1045,  595]],
#
#        [[1046,  490]],
#
#        [[1044,  707]],
#
#        [[ 593, 1037]],
#
#        [[ 927,  159]],
#
#        [[1043,  812]],
#
#        [[ 702, 1036]],
#
#        [[  58,   81]],
#
#        [[  58,  165]],
#
#        [[ 138,  815]],
#
#        [[ 873,   79]],
#
#        [[ 941, 1051]],
#
#        [[1040,  922]],
#
#        [[ 142,  161]],
#
#        [[  58,  220]],
#
#        [[  59,  141]],
#
#        [[ 813,   78]],
#
#        [[ 973, 1068]],
#
#        [[1051, 1068]],
#
#        [[ 548,   79]],
#
#        [[ 951,   79]],
#
#        [[ 131,  298]]])

# %%
# plotando os círculos na imagem
for i in edges:

    x,y = i.ravel()
    cv2.circle(xadrez, center=(x,y), radius=3, color=(0,255,0), thickness=-1)

plt.imshow(xadrez)

# %%
# leitura da imagem
realXadrez = cv2.imread('../../assets/xadrez-real.jpeg')
realXadrez = cv2.cvtColor(realXadrez, cv2.COLOR_BGR2RGB)
plt.imshow(realXadrez)

# %%
# imagem cinza
xadrezGrayReal = cv2.cvtColor(realXadrez, cv2.COLOR_BGR2GRAY)
plt.imshow(xadrezGrayReal, cmap='gray')

# %%
# aplicando o algoritmo
edgesReal = cv2.goodFeaturesToTrack(xadrezGrayReal, 500, 0.01, 10)
# convertendo para inteiro
edgesReal = np.int0(edgesReal)
# Out:
# /var/folders/xb/9xj62y794n3_9q3z4tbt47yc0000gn/T/ipykernel_84945/2896213925.py:4: DeprecationWarning: `np.int0` is a deprecated alias for `np.intp`.  (Deprecated NumPy 1.24)
#   edgesReal = np.int0(edgesReal)

# %%
# plotando os círculos na imagem
for i in edgesReal:

    x,y = i.ravel()
    cv2.circle(realXadrez, center=(x,y), radius=3, color=(0,255,0), thickness=4)

plt.imshow(realXadrez)
